# %%
mV = 90
uV = mV * 1000
R_uOhm = 15e3
uA = uV / R_uOhm

print(f"mV = {mV}")
print(f"uV = {uV}")
print(f"R_uOhm = {R_uOhm}")
print(f"uA = {uA}")
# Out:
# mV = 90
# uV = 90000
# R_uOhm = 15000.0
# uA = 6.0
